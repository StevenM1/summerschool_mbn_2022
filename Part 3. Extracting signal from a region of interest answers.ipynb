# %% [markdown]
# # Part 3. Extracting signal from a region of interest
#
# In Part 1, we preprocessed the data (or, at least, explored *how* you could go about preprocessing your data). Let's just use the `fmriprep`-preprocessed data for the remainder of the tutorial. Here, we will extract signal from a region of interest: striatum. Striatum is part of the Basal Ganglia, and has repeatedly been implicated in response caution adjustments (e.g., [Forstmann et al 2008](http://www.pnas.org/content/105/45/17538/#F2); [Van Maanen et al 2011](http://www.jneurosci.org/content/31/48/17488)). In Part 3 and 4 of this tutorial, we'll see if we can replicate this result.
#
# In order to extract signal from a region of interest, we need a mask that tells us where this ROI lies in the brain. Since `fmriprep` registered ('normalized') our data to MNI152-space, we can use a mask from an atlas in MNI152-space.

# %%
import matplotlib.pyplot as plt
import numpy as np
import nibabel as nib
from nipype.interfaces import fsl
import nilearn.datasets

# %matplotlib inline

# %% [markdown]
# ## A look at masks

# %% [markdown]
# In the directory `/data/masks/` you can find various masks, including one for the left and one for the right striatum

# %%
# !ls /data/masks/MNI152-2mm
# Out:
# GPe_L.nii.gz  GPi_L.nii.gz  STR_L.nii.gz
# GPe_R.nii.gz  GPi_R.nii.gz  STR_R.nii.gz

# %% [markdown]
# Let's load a mask and see what it looks like.

# %%
str_l = nib.load('/data/masks/MNI152-2mm/STR_L.nii.gz').get_fdata()
plt.imshow(str_l[:, 68, :].T, origin='lower', cmap=plt.cm.hot)

# %% [markdown]
# Note that this is a *probabilistic* map. The colors in the above plot indicate the *probability* for each voxel that is is part of any given individual's left striatum. Further, probabilities of 0 lead to a black pixel in the plot above.

# %% [markdown]
# Let's mask all voxels that have a probability of 50% or less of belonging to any of the striatal parts. This way, they won't end up as black pixels when we plot them, but become transparant

# %%
str_l = np.ma.masked_less(str_l, 0.5)

# %% [markdown]
# Now, `str_l` is a 3D-matrix indicating for each voxel the probability that it belongs to the left striatum. What does this look like?

# %%
plt.imshow(str_l[:, 68, :].T, origin='lower', cmap=plt.cm.hot)

# %% [markdown]
# The background is now white instead of black, which doesn't help much. But now we can superimpose this mask on an MNI152 template

# %%
# Load the MNI template
mni = nib.load('/data/mni_icbm152_nlin_asym_09c/2mm_T1.nii.gz').get_fdata()

# %%
plt.figure(figsize=(20, 10))

plt.subplot(131)
plt.imshow(mni[:, 68, :].T,origin='lower', cmap=plt.cm.gray)
plt.imshow(str_l[:, 68, :].T,origin='lower', cmap=plt.cm.hot)
plt.grid('off')

plt.subplot(132)
plt.imshow(mni[38, :, :].T,origin='lower', cmap=plt.cm.gray)
plt.imshow(str_l[38, :, :].T,origin='lower', cmap=plt.cm.hot)
plt.grid('off')

plt.subplot(133)
plt.imshow(mni[:, :, 40].T,origin='lower', cmap=plt.cm.gray)
plt.imshow(str_l[:, :, 40].T,origin='lower', cmap=plt.cm.hot)
plt.grid('off')

# %% [markdown]
# And that's where left striatum is located probabilistically

# %% [markdown]
# Note that the `str_l` variable is a kind of image. You can apply image processing tools to it; for example, to find the center of mass (this is how the slices plotting above were chosen)

# %%
import scipy as sp
from scipy import ndimage
com = ndimage.center_of_mass(str_l)
com
# Out:
# (38.03372758952017, 68.37898108274199, 40.79747377169487)

# %% [markdown]
# 1) Can you make the same plots for right striatum? Find the center of mass, and plot it on an MNI152-brain

# %%
str_r = nib.load('/data/masks/MNI152-2mm/STR_R.nii.gz').get_fdata()
str_r = np.ma.masked_less(str_r, 0.5)
com = ndimage.center_of_mass(str_r)

plt.figure(figsize=(20, 10))

plt.subplot(131)
plt.imshow(mni[:, int(com[1]), :].T,origin='lower', cmap=plt.cm.gray)
plt.imshow(str_r[:, int(com[1]), :].T,origin='lower', cmap=plt.cm.hot)
plt.grid('off')

plt.subplot(132)
plt.imshow(mni[int(com[0]), :, :].T,origin='lower', cmap=plt.cm.gray)
plt.imshow(str_r[int(com[0]), :, :].T,origin='lower', cmap=plt.cm.hot)
plt.grid('off')

plt.subplot(133)
plt.imshow(mni[:, :, int(com[2])].T,origin='lower', cmap=plt.cm.gray)
plt.imshow(str_r[:, :, int(com[2])].T,origin='lower', cmap=plt.cm.hot)
plt.grid('off')

# %% [markdown]
# ## Extracting signal from a masked region
# Back to Nipype. Nipype contains interfaces that allows you to extract a time series *meaned* over a region of interest. The interface is called `ImageMeants()`. Let's first see how this works

# %%
# We'll need these libraries below
from nipype.interfaces import fsl
import nipype.pipeline.engine as pe
import nipype.interfaces.io as nio

# %%
# !ls /data/deriv/fmriprep/sub-483/func
# Out:
# sub-483_task-SAT_run-1_desc-confounds_regressors.json
# sub-483_task-SAT_run-1_desc-confounds_regressors.tsv
# sub-483_task-SAT_run-1_space-MNI152NLin2009cAsym_boldref.nii.gz
# sub-483_task-SAT_run-1_space-MNI152NLin2009cAsym_desc-aparcaseg_dseg.nii.gz
# sub-483_task-SAT_run-1_space-MNI152NLin2009cAsym_desc-aseg_dseg.nii.gz
# sub-483_task-SAT_run-1_space-MNI152NLin2009cAsym_desc-brain_mask.json
# sub-483_task-SAT_run-1_space-MNI152NLin2009cAsym_desc-brain_mask.nii.gz
# sub-483_task-SAT_run-1_space-MNI152NLin2009cAsym_desc-preproc_bold.json
# sub-483_task-SAT_run-1_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# sub-483_task-SAT_run-2_desc-confounds_regressors.json
# sub-483_task-SAT_run-2_desc-confounds_regressors.tsv
# sub-483_task-SAT_run-2_space-MNI152NLin2009cAsym_boldref.nii.gz
# sub-483_task-SAT_run-2_space-MNI152NLin2009cAsym_desc-aparcaseg_dseg.nii.gz
# sub-483_task-SAT_run-2_space-MNI152NLin2009cAsym_desc-aseg_dseg.nii.gz
# sub-483_task-SAT_run-2_space-MNI152NLin2009cAsym_desc-brain_mask.json
# sub-483_task-SAT_run-2_space-MNI152NLin2009cAsym_desc-brain_mask.nii.gz
# sub-483_task-SAT_run-2_space-MNI152NLin2009cAsym_desc-preproc_bold.json
# sub-483_task-SAT_run-2_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz

# %%
extracter = fsl.ImageMeants()
extracter.inputs.in_file = '/data/deriv/fmriprep/sub-483/func/sub-483_task-SAT_run-1_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz'
extracter.inputs.mask = '/data/masks/MNI152-epi/STR_L.nii.gz'

# %%
r = extracter.run()
r.outputs
# Out:
# out_file = /home/neuro/model_based_fmri/sub-483_task-SAT_run-1_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt

# %% [markdown]
# Now, using `np.loadtxt(<path_to_txt_file>)`, you can load the output.
#
# 2) Can you plot the data?

# %%
raw_str_data = np.loadtxt(r.outputs.out_file)   # here we load
plt.plot(raw_str_data) # plot

# %% [markdown]
# ## Making a pipeline
# Now we semi-manually extracted a single subject's time series signal meaned over striatum. We could do this in the same way for all subjects, but it's much more efficient to make a pipeline. Let's make one that extracts the time series meaned over striatum for all participants. First, set-up the nodes we want to use

# %%
# This is the node that extracts signal
extracter = pe.MapNode(fsl.ImageMeants(), iterfield='in_file', name='extract_mean_ts')

# %% [markdown]
# Note that this is a [MapNode](https://pythonhosted.org/nipype/api/generated/nipype.pipeline.engine.nodes.html#mapnode) rather than a regular Node; i.e., a Node the receives a list of inputs and applies the same interface to each element of the list.
#
# 3) In the cell below, create/fill:
# - the template for where to find the masks
# - the template for where to find the functional data (similar to Part 1)
# - all subject ids at selector.iterator.
# - fill in the mask names at selector.iterator

# %%
# Here, we set-up a SelectFile-Node
templates = {
    'mask': '/data/masks/MNI152-epi/{mask}.nii.gz',  # NB: use folder "MNI152-epi" here instead of "MNI152-2mm"
    'func': '/data/deriv/fmriprep/sub-{subject_id}/func/sub-{subject_id}_task-SAT_run-*_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz'
}

selector = pe.Node(nio.SelectFiles(templates=templates), name='file_selector')
selector.iterables = [('subject_id', ['197', '372', '381', '471', '483', '498', '523', '544', '548', '549', '551', '552', '553', '554', '555', '558', '559']), 
                      ('mask', ['STR_L', 'STR_R'])]


# A datasink is useful for exporting. Remember the base_directory - this is where the data will be saved later
ds = pe.Node(nio.DataSink(base_directory='/data/extracted_signals'), 
             name='datasink')

# %% [markdown]
# Then, combine everything in a Workflow.
#
# 4) In the cell below, make the right connections in the workflow: you want to connect the `selector` to the `extractor` in two ways. Remember that you can call `fsl.ImageMeants.help()` to see the input argument names

# %%
workflow = pe.Workflow(base_dir='/data/workflow_folders/', 
                       name='extract_striatum_signal')

# Connect the Nodes
workflow.connect(selector, 'mask', extracter, 'mask')
workflow.connect(selector, 'func', extracter, 'in_file')
workflow.connect(extracter, 'out_file', ds, 'extracted_timeseries')

# Make a graph to visualize what we did..
workflow.write_graph('graph.dot', format='png')
from IPython.display import Image
Image('/data/workflow_folders/extract_striatum_signal/graph.png')
# Out:
# 220711-13:27:04,753 nipype.workflow INFO:
# 	 Generated workflow graph: /data/workflow_folders/extract_striatum_signal/graph.png (graph2use=hierarchical, simple_form=True).

# %% [markdown]
# And we're ready to run

# %%
workflow.run('MultiProc', plugin_args={'n_proc': 3})
# Out:
# 220711-13:27:04,774 nipype.workflow INFO:
# 	 Workflow extract_striatum_signal settings: ['check', 'execution', 'logging', 'monitoring']
# 220711-13:27:04,904 nipype.workflow INFO:
# 	 Running in parallel.
# 220711-13:27:04,909 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 34 jobs ready. Free memory (GB): 338.90/338.90, Free processors: 32/32.
# 220711-13:27:05,241 nipype.workflow INFO:
# 	 [Node] Setting-up "extract_striatum_signal.file_selector" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_L_subject_id_197/file_selector".
# 220711-13:27:05,245 nipype.workflow INFO:
# 	 [Node] Setting-up "extract_striatum_signal.file_selector" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_L_subject_id_372/file_selector".
# 220711-13:27:05,243 nipype.workflow INFO:
# 	 [Node] Setting-up "extract_striatum_signal.file_selector" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_R_subject_id_197/file_selector".
# 220711-13:27:05,247 nipype.workflow INFO:
# 	 [Node] Setting-up "extract_striatum_signal.file_selector" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_R_subject_id_372/file_selector".
# 220711-13:27:05,248 nipype.workflow INFO:
# 	 [Node] Setting-up "extract_striatum_signal.file_selector" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_L_subject_id_381/file_selector".
# 220711-13:27:05,250 nipype.workflow INFO:
# 	 [Node] Setting-up "extract_striatum_signal.file_selector" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_R_subject_id_381/file_selector".
# 220711-13:27:05,253 nipype.workflow INFO:
# 	 [Node] Setting-up "extract_striatum_signal.file_selector" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_L_subject_id_471/file_selector".
# 220711-13:27:05,255 nipype.workflow INFO:
# 	 [Node] Setting-up "extract_striatum_signal.file_selector" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_R_subject_id_471/file_selector".
# 220711-13:27:05,256 nipype.workflow INFO:
# 	 [Node] Setting-up "extract_striatum_signal.file_selector" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_L_subject_id_483/file_selector".
# 220711-13:27:05,262 nipype.workflow INFO:
# 	 [Node] Setting-up "extract_striatum_signal.file_selector" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_R_subject_id_483/file_selector".
# 220711-13:27:05,265 nipype.workflow INFO:
# 	 [Node] Executing "file_selector" <nipype.interfaces.io.SelectFiles>
# 220711-13:27:05,267 nipype.workflow INFO:
# 	 [Node] Executing "file_selector" <nipype.interfaces.io.SelectFiles>
# 220711-13:27:05,270 nipype.workflow INFO:
# 	 [Node] Executing "file_selector" <nipype.interfaces.io.SelectFiles>
# 220711-13:27:05,267 nipype.workflow INFO:
# 	 [Node] Executing "file_selector" <nipype.interfaces.io.SelectFiles>
# 220711-13:27:05,266 nipype.workflow INFO:
# 	 [Node] Executing "file_selector" <nipype.interfaces.io.SelectFiles>
# 220711-13:27:05,267 nipype.workflow INFO:
# 	 [Node] Executing "file_selector" <nipype.interfaces.io.SelectFiles>
# 220711-13:27:05,266 nipype.workflow INFO:
# 	 [Node] Setting-up "extract_striatum_signal.file_selector" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_L_subject_id_498/file_selector".
# 220711-13:27:05,271 nipype.workflow INFO:
# 	 [Node] Finished "file_selector", elapsed time 0.00172s.
# 220711-13:27:05,270 nipype.workflow INFO:
# 	 [Node] Setting-up "extract_striatum_signal.file_selector" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_R_subject_id_498/file_selector".
# 220711-13:27:05,273 nipype.workflow INFO:
# 	 [Node] Setting-up "extract_striatum_signal.file_selector" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_L_subject_id_523/file_selector".
# 220711-13:27:05,275 nipype.workflow INFO:
# 	 [Node] Finished "file_selector", elapsed time 0.007999s.
# 220711-13:27:05,276 nipype.workflow INFO:
# 	 [Node] Finished "file_selector", elapsed time 0.006262s.
# 220711-13:27:05,276 nipype.workflow INFO:
# 	 [Node] Finished "file_selector", elapsed time 0.005532s.
# 220711-13:27:05,275 nipype.workflow INFO:
# 	 [Node] Setting-up "extract_striatum_signal.file_selector" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_R_subject_id_523/file_selector".
# 220711-13:27:05,277 nipype.workflow INFO:
# 	 [Node] Finished "file_selector", elapsed time 0.007118s.
# 220711-13:27:05,278 nipype.workflow INFO:
# 	 [Node] Setting-up "extract_striatum_signal.file_selector" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_L_subject_id_544/file_selector".
# 220711-13:27:05,280 nipype.workflow INFO:
# 	 [Node] Setting-up "extract_striatum_signal.file_selector" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_R_subject_id_544/file_selector".
# 220711-13:27:05,282 nipype.workflow INFO:
# 	 [Node] Setting-up "extract_striatum_signal.file_selector" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_L_subject_id_548/file_selector".
# 220711-13:27:05,284 nipype.workflow INFO:
# 	 [Node] Finished "file_selector", elapsed time 0.011579s.
# 220711-13:27:05,284 nipype.workflow INFO:
# 	 [Node] Setting-up "extract_striatum_signal.file_selector" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_R_subject_id_548/file_selector".
# 220711-13:27:05,286 nipype.workflow INFO:
# 	 [Node] Setting-up "extract_striatum_signal.file_selector" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_L_subject_id_549/file_selector".
# 220711-13:27:05,289 nipype.workflow INFO:
# 	 [Node] Setting-up "extract_striatum_signal.file_selector" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_R_subject_id_549/file_selector".
# 220711-13:27:05,290 nipype.workflow INFO:
# 	 [Node] Setting-up "extract_striatum_signal.file_selector" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_L_subject_id_551/file_selector".
# 220711-13:27:05,292 nipype.workflow INFO:
# 	 [Node] Setting-up "extract_striatum_signal.file_selector" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_R_subject_id_551/file_selector".
# 220711-13:27:05,292 nipype.workflow INFO:
# 	 [Node] Setting-up "extract_striatum_signal.file_selector" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_L_subject_id_552/file_selector".
# 220711-13:27:05,294 nipype.workflow INFO:
# 	 [Node] Setting-up "extract_striatum_signal.file_selector" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_R_subject_id_552/file_selector".
# 220711-13:27:05,299 nipype.workflow INFO:
# 	 [Node] Setting-up "extract_striatum_signal.file_selector" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_L_subject_id_554/file_selector".
# 220711-13:27:05,302 nipype.workflow INFO:
# 	 [Node] Setting-up "extract_striatum_signal.file_selector" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_L_subject_id_555/file_selector".
# 220711-13:27:05,301 nipype.workflow INFO:
# 	 [Node] Setting-up "extract_striatum_signal.file_selector" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_R_subject_id_554/file_selector".
# 220711-13:27:05,304 nipype.workflow INFO:
# 	 [Node] Setting-up "extract_striatum_signal.file_selector" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_R_subject_id_555/file_selector".
# 220711-13:27:05,305 nipype.workflow INFO:
# 	 [Node] Setting-up "extract_striatum_signal.file_selector" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_L_subject_id_558/file_selector".
# 220711-13:27:05,306 nipype.workflow INFO:
# 	 [Node] Setting-up "extract_striatum_signal.file_selector" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_R_subject_id_558/file_selector".
# 220711-13:27:05,326 nipype.workflow INFO:
# 	 [Node] Executing "file_selector" <nipype.interfaces.io.SelectFiles>
# 220711-13:27:05,297 nipype.workflow INFO:
# 	 [Node] Setting-up "extract_striatum_signal.file_selector" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_R_subject_id_553/file_selector".
# 220711-13:27:05,295 nipype.workflow INFO:
# 	 [Node] Setting-up "extract_striatum_signal.file_selector" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_L_subject_id_553/file_selector".
# 220711-13:27:05,340 nipype.workflow INFO:
# 	 [Node] Finished "file_selector", elapsed time 0.011443s.
# 220711-13:27:05,348 nipype.workflow INFO:
# 	 [Node] Executing "file_selector" <nipype.interfaces.io.SelectFiles>
# 220711-13:27:05,348 nipype.workflow INFO:
# 	 [Node] Executing "file_selector" <nipype.interfaces.io.SelectFiles>
# 220711-13:27:05,353 nipype.workflow INFO:
# 	 [Node] Finished "file_selector", elapsed time 0.001804s.
# 220711-13:27:05,356 nipype.workflow INFO:
# 	 [Node] Executing "file_selector" <nipype.interfaces.io.SelectFiles>
# 220711-13:27:05,356 nipype.workflow INFO:
# 	 [Node] Executing "file_selector" <nipype.interfaces.io.SelectFiles>
# 220711-13:27:05,356 nipype.workflow INFO:
# 	 [Node] Finished "file_selector", elapsed time 0.003376s.
# 220711-13:27:05,358 nipype.workflow INFO:
# 	 [Node] Executing "file_selector" <nipype.interfaces.io.SelectFiles>
# 220711-13:27:05,358 nipype.workflow INFO:
# 	 [Node] Executing "file_selector" <nipype.interfaces.io.SelectFiles>
# 220711-13:27:05,358 nipype.workflow INFO:
# 	 [Node] Executing "file_selector" <nipype.interfaces.io.SelectFiles>
# 220711-13:27:05,358 nipype.workflow INFO:
# 	 [Node] Executing "file_selector" <nipype.interfaces.io.SelectFiles>
# 220711-13:27:05,358 nipype.workflow INFO:
# 	 [Node] Executing "file_selector" <nipype.interfaces.io.SelectFiles>
# 220711-13:27:05,358 nipype.workflow INFO:
# 	 [Node] Executing "file_selector" <nipype.interfaces.io.SelectFiles>
# 220711-13:27:05,358 nipype.workflow INFO:
# 	 [Node] Executing "file_selector" <nipype.interfaces.io.SelectFiles>
# 220711-13:27:05,358 nipype.workflow INFO:
# 	 [Node] Executing "file_selector" <nipype.interfaces.io.SelectFiles>
# 220711-13:27:05,358 nipype.workflow INFO:
# 	 [Node] Executing "file_selector" <nipype.interfaces.io.SelectFiles>
# 220711-13:27:05,359 nipype.workflow INFO:
# 	 [Node] Executing "file_selector" <nipype.interfaces.io.SelectFiles>
# 220711-13:27:05,366 nipype.workflow INFO:
# 	 [Node] Finished "file_selector", elapsed time 0.006176s.
# 220711-13:27:05,366 nipype.workflow INFO:
# 	 [Node] Finished "file_selector", elapsed time 0.004091s.
# 220711-13:27:05,367 nipype.workflow INFO:
# 	 [Node] Finished "file_selector", elapsed time 0.003706s.
# 220711-13:27:05,367 nipype.workflow INFO:
# 	 [Node] Finished "file_selector", elapsed time 0.003599s.
# 220711-13:27:05,368 nipype.workflow INFO:
# 	 [Node] Finished "file_selector", elapsed time 0.003867s.
# 220711-13:27:05,368 nipype.workflow INFO:
# 	 [Node] Finished "file_selector", elapsed time 0.004122s.
# 220711-13:27:05,369 nipype.workflow INFO:
# 	 [Node] Finished "file_selector", elapsed time 0.004798s.
# 220711-13:27:05,372 nipype.workflow INFO:
# 	 [Node] Finished "file_selector", elapsed time 0.009163s.
# 220711-13:27:05,374 nipype.workflow INFO:
# 	 [Node] Finished "file_selector", elapsed time 0.013593s.
# 220711-13:27:05,375 nipype.workflow INFO:
# 	 [Node] Finished "file_selector", elapsed time 0.011569s.
# 220711-13:27:05,387 nipype.workflow INFO:
# 	 [Node] Finished "file_selector", elapsed time 0.024291s.
# 220711-13:27:05,388 nipype.workflow INFO:
# 	 [Node] Finished "file_selector", elapsed time 0.023525s.
# 220711-13:27:05,404 nipype.workflow INFO:
# 	 [Node] Executing "file_selector" <nipype.interfaces.io.SelectFiles>
# 220711-13:27:05,404 nipype.workflow INFO:
# 	 [Node] Executing "file_selector" <nipype.interfaces.io.SelectFiles>
# 220711-13:27:05,404 nipype.workflow INFO:
# 	 [Node] Executing "file_selector" <nipype.interfaces.io.SelectFiles>
# 220711-13:27:05,404 nipype.workflow INFO:
# 	 [Node] Executing "file_selector" <nipype.interfaces.io.SelectFiles>
# 220711-13:27:05,404 nipype.workflow INFO:
# 	 [Node] Executing "file_selector" <nipype.interfaces.io.SelectFiles>
# 220711-13:27:05,404 nipype.workflow INFO:
# 	 [Node] Executing "file_selector" <nipype.interfaces.io.SelectFiles>
# 220711-13:27:05,405 nipype.workflow INFO:
# 	 [Node] Executing "file_selector" <nipype.interfaces.io.SelectFiles>
# 220711-13:27:05,411 nipype.workflow INFO:
# 	 [Node] Finished "file_selector", elapsed time 0.002503s.
# 220711-13:27:05,412 nipype.workflow INFO:
# 	 [Node] Finished "file_selector", elapsed time 0.002555s.
# 220711-13:27:05,412 nipype.workflow INFO:
# 	 [Node] Finished "file_selector", elapsed time 0.003013s.
# 220711-13:27:05,413 nipype.workflow INFO:
# 	 [Node] Finished "file_selector", elapsed time 0.003521s.
# 220711-13:27:05,414 nipype.workflow INFO:
# 	 [Node] Finished "file_selector", elapsed time 0.003254s.
# 220711-13:27:05,414 nipype.workflow INFO:
# 	 [Node] Finished "file_selector", elapsed time 0.004246s.
# 220711-13:27:05,415 nipype.workflow INFO:
# 	 [Node] Finished "file_selector", elapsed time 0.004171s.
# 220711-13:27:05,416 nipype.workflow INFO:
# 	 [Node] Executing "file_selector" <nipype.interfaces.io.SelectFiles>
# 220711-13:27:05,416 nipype.workflow INFO:
# 	 [Node] Executing "file_selector" <nipype.interfaces.io.SelectFiles>
# 220711-13:27:05,417 nipype.workflow INFO:
# 	 [Node] Executing "file_selector" <nipype.interfaces.io.SelectFiles>
# 220711-13:27:05,417 nipype.workflow INFO:
# 	 [Node] Executing "file_selector" <nipype.interfaces.io.SelectFiles>
# 220711-13:27:05,421 nipype.workflow INFO:
# 	 [Node] Finished "file_selector", elapsed time 0.001583s.
# 220711-13:27:05,423 nipype.workflow INFO:
# 	 [Node] Finished "file_selector", elapsed time 0.002762s.
# 220711-13:27:05,428 nipype.workflow INFO:
# 	 [Node] Finished "file_selector", elapsed time 0.00714s.
# 220711-13:27:05,428 nipype.workflow INFO:
# 	 [Node] Finished "file_selector", elapsed time 0.008294s.
# 220711-13:27:06,913 nipype.workflow INFO:
# 	 [Job 0] Completed (extract_striatum_signal.file_selector).
# 220711-13:27:06,917 nipype.workflow INFO:
# 	 [Job 1] Completed (extract_striatum_signal.file_selector).
# 220711-13:27:06,920 nipype.workflow INFO:
# 	 [Job 2] Completed (extract_striatum_signal.file_selector).
# 220711-13:27:06,922 nipype.workflow INFO:
# 	 [Job 3] Completed (extract_striatum_signal.file_selector).
# 220711-13:27:06,924 nipype.workflow INFO:
# 	 [Job 4] Completed (extract_striatum_signal.file_selector).
# 220711-13:27:06,926 nipype.workflow INFO:
# 	 [Job 5] Completed (extract_striatum_signal.file_selector).
# 220711-13:27:06,929 nipype.workflow INFO:
# 	 [Job 6] Completed (extract_striatum_signal.file_selector).
# 220711-13:27:06,931 nipype.workflow INFO:
# 	 [Job 7] Completed (extract_striatum_signal.file_selector).
# 220711-13:27:06,933 nipype.workflow INFO:
# 	 [Job 8] Completed (extract_striatum_signal.file_selector).
# 220711-13:27:06,934 nipype.workflow INFO:
# 	 [Job 9] Completed (extract_striatum_signal.file_selector).
# 220711-13:27:06,936 nipype.workflow INFO:
# 	 [Job 10] Completed (extract_striatum_signal.file_selector).
# 220711-13:27:06,937 nipype.workflow INFO:
# 	 [Job 11] Completed (extract_striatum_signal.file_selector).
# 220711-13:27:06,938 nipype.workflow INFO:
# 	 [Job 12] Completed (extract_striatum_signal.file_selector).
# 220711-13:27:06,940 nipype.workflow INFO:
# 	 [Job 13] Completed (extract_striatum_signal.file_selector).
# 220711-13:27:06,941 nipype.workflow INFO:
# 	 [Job 14] Completed (extract_striatum_signal.file_selector).
# 220711-13:27:06,942 nipype.workflow INFO:
# 	 [Job 15] Completed (extract_striatum_signal.file_selector).
# 220711-13:27:06,943 nipype.workflow INFO:
# 	 [Job 16] Completed (extract_striatum_signal.file_selector).
# 220711-13:27:06,944 nipype.workflow INFO:
# 	 [Job 17] Completed (extract_striatum_signal.file_selector).
# 220711-13:27:06,945 nipype.workflow INFO:
# 	 [Job 18] Completed (extract_striatum_signal.file_selector).
# 220711-13:27:06,946 nipype.workflow INFO:
# 	 [Job 19] Completed (extract_striatum_signal.file_selector).
# 220711-13:27:06,947 nipype.workflow INFO:
# 	 [Job 20] Completed (extract_striatum_signal.file_selector).
# 220711-13:27:06,948 nipype.workflow INFO:
# 	 [Job 21] Completed (extract_striatum_signal.file_selector).
# 220711-13:27:06,949 nipype.workflow INFO:
# 	 [Job 22] Completed (extract_striatum_signal.file_selector).
# 220711-13:27:06,950 nipype.workflow INFO:
# 	 [Job 23] Completed (extract_striatum_signal.file_selector).
# 220711-13:27:06,951 nipype.workflow INFO:
# 	 [Job 24] Completed (extract_striatum_signal.file_selector).
# 220711-13:27:06,952 nipype.workflow INFO:
# 	 [Job 25] Completed (extract_striatum_signal.file_selector).
# 220711-13:27:06,955 nipype.workflow INFO:
# 	 [Job 26] Completed (extract_striatum_signal.file_selector).
# 220711-13:27:06,956 nipype.workflow INFO:
# 	 [Job 27] Completed (extract_striatum_signal.file_selector).
# 220711-13:27:06,957 nipype.workflow INFO:
# 	 [Job 28] Completed (extract_striatum_signal.file_selector).
# 220711-13:27:06,958 nipype.workflow INFO:
# 	 [Job 29] Completed (extract_striatum_signal.file_selector).
# 220711-13:27:06,959 nipype.workflow INFO:
# 	 [Job 30] Completed (extract_striatum_signal.file_selector).
# 220711-13:27:06,960 nipype.workflow INFO:
# 	 [Job 31] Completed (extract_striatum_signal.file_selector).
# 220711-13:27:06,962 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 34 jobs ready. Free memory (GB): 338.90/338.90, Free processors: 32/32.
# 220711-13:27:07,67 nipype.workflow INFO:
# 	 [Node] Setting-up "extract_striatum_signal.file_selector" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_L_subject_id_559/file_selector".
# 220711-13:27:07,71 nipype.workflow INFO:
# 	 [Node] Setting-up "extract_striatum_signal.file_selector" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_R_subject_id_559/file_selector".
# 220711-13:27:07,78 nipype.workflow INFO:
# 	 [Node] Executing "file_selector" <nipype.interfaces.io.SelectFiles>
# 220711-13:27:07,93 nipype.workflow INFO:
# 	 [Node] Finished "file_selector", elapsed time 0.012019s.
# 220711-13:27:07,105 nipype.workflow INFO:
# 	 [Node] Executing "file_selector" <nipype.interfaces.io.SelectFiles>
# 220711-13:27:07,109 nipype.workflow INFO:
# 	 [Node] Finished "file_selector", elapsed time 0.001162s.
# 220711-13:27:08,914 nipype.workflow INFO:
# 	 [Job 32] Completed (extract_striatum_signal.file_selector).
# 220711-13:27:08,917 nipype.workflow INFO:
# 	 [Job 33] Completed (extract_striatum_signal.file_selector).
# 220711-13:27:08,922 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 66 jobs ready. Free memory (GB): 338.90/338.90, Free processors: 32/32.
# 220711-13:27:09,29 nipype.workflow INFO:
# 	 [Job 102] Cached (_extract_mean_ts0).
# 220711-13:27:09,31 nipype.workflow INFO:
# 	 [Job 103] Cached (_extract_mean_ts1).
# 220711-13:27:09,33 nipype.workflow INFO:
# 	 [Job 104] Cached (_extract_mean_ts0).
# 220711-13:27:09,35 nipype.workflow INFO:
# 	 [Job 105] Cached (_extract_mean_ts1).
# 220711-13:27:09,37 nipype.workflow INFO:
# 	 [Job 106] Cached (_extract_mean_ts0).
# 220711-13:27:09,39 nipype.workflow INFO:
# 	 [Job 107] Cached (_extract_mean_ts1).
# 220711-13:27:09,41 nipype.workflow INFO:
# 	 [Job 108] Cached (_extract_mean_ts0).
# 220711-13:27:09,43 nipype.workflow INFO:
# 	 [Job 109] Cached (_extract_mean_ts1).
# 220711-13:27:09,45 nipype.workflow INFO:
# 	 [Job 110] Cached (_extract_mean_ts0).
# 220711-13:27:09,46 nipype.workflow INFO:
# 	 [Job 111] Cached (_extract_mean_ts1).
# 220711-13:27:09,48 nipype.workflow INFO:
# 	 [Job 112] Cached (_extract_mean_ts0).
# 220711-13:27:09,49 nipype.workflow INFO:
# 	 [Job 113] Cached (_extract_mean_ts1).
# 220711-13:27:09,51 nipype.workflow INFO:
# 	 [Job 114] Cached (_extract_mean_ts0).
# 220711-13:27:09,52 nipype.workflow INFO:
# 	 [Job 115] Cached (_extract_mean_ts1).
# 220711-13:27:09,54 nipype.workflow INFO:
# 	 [Job 116] Cached (_extract_mean_ts0).
# 220711-13:27:09,55 nipype.workflow INFO:
# 	 [Job 117] Cached (_extract_mean_ts1).
# 220711-13:27:09,57 nipype.workflow INFO:
# 	 [Job 118] Cached (_extract_mean_ts0).
# 220711-13:27:09,58 nipype.workflow INFO:
# 	 [Job 119] Cached (_extract_mean_ts1).
# 220711-13:27:09,59 nipype.workflow INFO:
# 	 [Job 120] Cached (_extract_mean_ts0).
# 220711-13:27:09,61 nipype.workflow INFO:
# 	 [Job 121] Cached (_extract_mean_ts1).
# 220711-13:27:09,63 nipype.workflow INFO:
# 	 [Job 122] Cached (_extract_mean_ts0).
# 220711-13:27:09,65 nipype.workflow INFO:
# 	 [Job 123] Cached (_extract_mean_ts1).
# 220711-13:27:09,67 nipype.workflow INFO:
# 	 [Job 124] Cached (_extract_mean_ts0).
# 220711-13:27:09,69 nipype.workflow INFO:
# 	 [Job 125] Cached (_extract_mean_ts1).
# 220711-13:27:09,71 nipype.workflow INFO:
# 	 [Job 126] Cached (_extract_mean_ts0).
# 220711-13:27:09,73 nipype.workflow INFO:
# 	 [Job 127] Cached (_extract_mean_ts1).
# 220711-13:27:09,75 nipype.workflow INFO:
# 	 [Job 128] Cached (_extract_mean_ts0).
# 220711-13:27:09,77 nipype.workflow INFO:
# 	 [Job 129] Cached (_extract_mean_ts1).
# 220711-13:27:09,79 nipype.workflow INFO:
# 	 [Job 130] Cached (_extract_mean_ts0).
# 220711-13:27:09,80 nipype.workflow INFO:
# 	 [Job 131] Cached (_extract_mean_ts1).
# 220711-13:27:09,82 nipype.workflow INFO:
# 	 [Job 132] Cached (_extract_mean_ts0).
# 220711-13:27:09,83 nipype.workflow INFO:
# 	 [Job 133] Cached (_extract_mean_ts1).
# 220711-13:27:10,918 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 52 jobs ready. Free memory (GB): 338.90/338.90, Free processors: 32/32.
# 220711-13:27:11,8 nipype.workflow INFO:
# 	 [Job 34] Cached (extract_striatum_signal.extract_mean_ts).
# 220711-13:27:11,12 nipype.workflow INFO:
# 	 [Job 35] Cached (extract_striatum_signal.extract_mean_ts).
# 220711-13:27:11,16 nipype.workflow INFO:
# 	 [Job 36] Cached (extract_striatum_signal.extract_mean_ts).
# 220711-13:27:11,20 nipype.workflow INFO:
# 	 [Job 37] Cached (extract_striatum_signal.extract_mean_ts).
# 220711-13:27:11,24 nipype.workflow INFO:
# 	 [Job 38] Cached (extract_striatum_signal.extract_mean_ts).
# 220711-13:27:11,27 nipype.workflow INFO:
# 	 [Job 39] Cached (extract_striatum_signal.extract_mean_ts).
# 220711-13:27:11,31 nipype.workflow INFO:
# 	 [Job 40] Cached (extract_striatum_signal.extract_mean_ts).
# 220711-13:27:11,35 nipype.workflow INFO:
# 	 [Job 41] Cached (extract_striatum_signal.extract_mean_ts).
# 220711-13:27:11,39 nipype.workflow INFO:
# 	 [Job 42] Cached (extract_striatum_signal.extract_mean_ts).
# 220711-13:27:11,42 nipype.workflow INFO:
# 	 [Job 43] Cached (extract_striatum_signal.extract_mean_ts).
# 220711-13:27:11,46 nipype.workflow INFO:
# 	 [Job 44] Cached (extract_striatum_signal.extract_mean_ts).
# 220711-13:27:11,50 nipype.workflow INFO:
# 	 [Job 45] Cached (extract_striatum_signal.extract_mean_ts).
# 220711-13:27:11,54 nipype.workflow INFO:
# 	 [Job 46] Cached (extract_striatum_signal.extract_mean_ts).
# 220711-13:27:11,57 nipype.workflow INFO:
# 	 [Job 47] Cached (extract_striatum_signal.extract_mean_ts).
# 220711-13:27:11,61 nipype.workflow INFO:
# 	 [Job 48] Cached (extract_striatum_signal.extract_mean_ts).
# 220711-13:27:11,65 nipype.workflow INFO:
# 	 [Job 49] Cached (extract_striatum_signal.extract_mean_ts).
# 220711-13:27:11,67 nipype.workflow INFO:
# 	 [Job 134] Cached (_extract_mean_ts0).
# 220711-13:27:11,69 nipype.workflow INFO:
# 	 [Job 135] Cached (_extract_mean_ts1).
# 220711-13:27:11,71 nipype.workflow INFO:
# 	 [Job 136] Cached (_extract_mean_ts0).
# 220711-13:27:11,72 nipype.workflow INFO:
# 	 [Job 137] Cached (_extract_mean_ts1).
# 220711-13:27:11,74 nipype.workflow INFO:
# 	 [Job 138] Cached (_extract_mean_ts0).
# 220711-13:27:11,76 nipype.workflow INFO:
# 	 [Job 139] Cached (_extract_mean_ts1).
# 220711-13:27:11,77 nipype.workflow INFO:
# 	 [Job 140] Cached (_extract_mean_ts0).
# 220711-13:27:11,79 nipype.workflow INFO:
# 	 [Job 141] Cached (_extract_mean_ts1).
# 220711-13:27:11,80 nipype.workflow INFO:
# 	 [Job 142] Cached (_extract_mean_ts0).
# 220711-13:27:11,82 nipype.workflow INFO:
# 	 [Job 143] Cached (_extract_mean_ts1).
# 220711-13:27:11,83 nipype.workflow INFO:
# 	 [Job 144] Cached (_extract_mean_ts0).
# 220711-13:27:11,84 nipype.workflow INFO:
# 	 [Job 145] Cached (_extract_mean_ts1).
# 220711-13:27:11,86 nipype.workflow INFO:
# 	 [Job 146] Cached (_extract_mean_ts0).
# 220711-13:27:11,87 nipype.workflow INFO:
# 	 [Job 147] Cached (_extract_mean_ts1).
# 220711-13:27:11,88 nipype.workflow INFO:
# 	 [Job 148] Cached (_extract_mean_ts0).
# 220711-13:27:11,90 nipype.workflow INFO:
# 	 [Job 149] Cached (_extract_mean_ts1).
# 220711-13:27:12,920 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 44 jobs ready. Free memory (GB): 338.90/338.90, Free processors: 32/32.
# 220711-13:27:13,9 nipype.workflow INFO:
# 	 [Job 50] Cached (extract_striatum_signal.extract_mean_ts).
# 220711-13:27:13,13 nipype.workflow INFO:
# 	 [Job 51] Cached (extract_striatum_signal.extract_mean_ts).
# 220711-13:27:13,16 nipype.workflow INFO:
# 	 [Job 52] Cached (extract_striatum_signal.extract_mean_ts).
# 220711-13:27:13,20 nipype.workflow INFO:
# 	 [Job 53] Cached (extract_striatum_signal.extract_mean_ts).
# 220711-13:27:13,24 nipype.workflow INFO:
# 	 [Job 54] Cached (extract_striatum_signal.extract_mean_ts).
# 220711-13:27:13,28 nipype.workflow INFO:
# 	 [Job 55] Cached (extract_striatum_signal.extract_mean_ts).
# 220711-13:27:13,32 nipype.workflow INFO:
# 	 [Job 56] Cached (extract_striatum_signal.extract_mean_ts).
# 220711-13:27:13,35 nipype.workflow INFO:
# 	 [Job 57] Cached (extract_striatum_signal.extract_mean_ts).
# 220711-13:27:13,61 nipype.workflow INFO:
# 	 [Node] Setting-up "extract_striatum_signal.datasink" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_L_subject_id_197/datasink".
# 220711-13:27:13,79 nipype.workflow INFO:
# 	 [Node] Setting-up "extract_striatum_signal.datasink" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_R_subject_id_197/datasink".
# 220711-13:27:13,85 nipype.workflow INFO:
# 	 [Node] Executing "datasink" <nipype.interfaces.io.DataSink>
# 220711-13:27:13,88 nipype.workflow INFO:
# 	 [Node] Executing "datasink" <nipype.interfaces.io.DataSink>
# 220711-13:27:13,93 nipype.workflow INFO:
# 	 [Node] Finished "datasink", elapsed time 0.001089s.
# 220711-13:27:13,97 nipype.workflow INFO:
# 	 [Node] Finished "datasink", elapsed time 0.008617s.
# 220711-13:27:13,98 nipype.workflow INFO:
# 	 [Node] Setting-up "extract_striatum_signal.datasink" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_L_subject_id_372/datasink".
# 220711-13:27:13,110 nipype.workflow INFO:
# 	 [Node] Executing "datasink" <nipype.interfaces.io.DataSink>
# 220711-13:27:13,113 nipype.workflow INFO:
# 	 [Node] Finished "datasink", elapsed time 0.000674s.
# 220711-13:27:13,123 nipype.workflow INFO:
# 	 [Node] Setting-up "extract_striatum_signal.datasink" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_R_subject_id_372/datasink".
# 220711-13:27:13,134 nipype.workflow INFO:
# 	 [Node] Setting-up "extract_striatum_signal.datasink" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_L_subject_id_381/datasink".
# 220711-13:27:13,137 nipype.workflow INFO:
# 	 [Node] Executing "datasink" <nipype.interfaces.io.DataSink>
# 220711-13:27:13,141 nipype.workflow INFO:
# 	 [Node] Finished "datasink", elapsed time 0.001072s.
# 220711-13:27:13,144 nipype.workflow INFO:
# 	 [Node] Executing "datasink" <nipype.interfaces.io.DataSink>
# 220711-13:27:13,147 nipype.workflow INFO:
# 	 [Node] Finished "datasink", elapsed time 0.000675s.
# 220711-13:27:13,155 nipype.workflow INFO:
# 	 [Node] Setting-up "extract_striatum_signal.datasink" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_R_subject_id_381/datasink".
# 220711-13:27:13,165 nipype.workflow INFO:
# 	 [Node] Setting-up "extract_striatum_signal.datasink" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_L_subject_id_471/datasink".
# 220711-13:27:13,169 nipype.workflow INFO:
# 	 [Node] Setting-up "extract_striatum_signal.datasink" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_R_subject_id_471/datasink".
# 220711-13:27:13,178 nipype.workflow INFO:
# 	 [Node] Setting-up "extract_striatum_signal.datasink" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_L_subject_id_483/datasink".
# 220711-13:27:13,197 nipype.workflow INFO:
# 	 [Node] Setting-up "extract_striatum_signal.datasink" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_R_subject_id_483/datasink".
# 220711-13:27:13,209 nipype.workflow INFO:
# 	 [Node] Executing "datasink" <nipype.interfaces.io.DataSink>
# 220711-13:27:13,209 nipype.workflow INFO:
# 	 [Node] Executing "datasink" <nipype.interfaces.io.DataSink>
# 220711-13:27:13,210 nipype.workflow INFO:
# 	 [Node] Executing "datasink" <nipype.interfaces.io.DataSink>
# 220711-13:27:13,210 nipype.workflow INFO:
# 	 [Node] Executing "datasink" <nipype.interfaces.io.DataSink>
# 220711-13:27:13,210 nipype.workflow INFO:
# 	 [Node] Setting-up "extract_striatum_signal.datasink" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_L_subject_id_498/datasink".
# 220711-13:27:13,214 nipype.workflow INFO:
# 	 [Node] Finished "datasink", elapsed time 0.001449s.
# 220711-13:27:13,214 nipype.workflow INFO:
# 	 [Node] Finished "datasink", elapsed time 0.001442s.
# 220711-13:27:13,215 nipype.workflow INFO:
# 	 [Node] Finished "datasink", elapsed time 0.001312s.
# 220711-13:27:13,215 nipype.workflow INFO:
# 	 [Node] Finished "datasink", elapsed time 0.001357s.
# 220711-13:27:13,216 nipype.workflow INFO:
# 	 [Node] Executing "datasink" <nipype.interfaces.io.DataSink>
# 220711-13:27:13,219 nipype.workflow INFO:
# 	 [Node] Finished "datasink", elapsed time 0.000788s.
# 220711-13:27:13,227 nipype.workflow INFO:
# 	 [Node] Setting-up "extract_striatum_signal.datasink" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_R_subject_id_498/datasink".
# 220711-13:27:13,234 nipype.workflow INFO:
# 	 [Node] Executing "datasink" <nipype.interfaces.io.DataSink>
# 220711-13:27:13,237 nipype.workflow INFO:
# 	 [Node] Finished "datasink", elapsed time 0.00061s.
# 220711-13:27:13,243 nipype.workflow INFO:
# 	 [Node] Executing "datasink" <nipype.interfaces.io.DataSink>
# 220711-13:27:13,246 nipype.workflow INFO:
# 	 [Node] Finished "datasink", elapsed time 0.000712s.
# 220711-13:27:13,256 nipype.workflow INFO:
# 	 [Node] Setting-up "extract_striatum_signal.datasink" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_L_subject_id_523/datasink".
# 220711-13:27:13,285 nipype.workflow INFO:
# 	 [Node] Setting-up "extract_striatum_signal.datasink" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_R_subject_id_523/datasink".
# 220711-13:27:13,295 nipype.workflow INFO:
# 	 [Node] Executing "datasink" <nipype.interfaces.io.DataSink>
# 220711-13:27:13,297 nipype.workflow INFO:
# 	 [Node] Setting-up "extract_striatum_signal.datasink" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_L_subject_id_544/datasink".
# 220711-13:27:13,299 nipype.workflow INFO:
# 	 [Node] Finished "datasink", elapsed time 0.000985s.
# 220711-13:27:13,305 nipype.workflow INFO:
# 	 [Node] Executing "datasink" <nipype.interfaces.io.DataSink>
# 220711-13:27:13,308 nipype.workflow INFO:
# 	 [Node] Finished "datasink", elapsed time 0.000871s.
# 220711-13:27:13,310 nipype.workflow INFO:
# 	 [Node] Executing "datasink" <nipype.interfaces.io.DataSink>
# 220711-13:27:13,313 nipype.workflow INFO:
# 	 [Node] Finished "datasink", elapsed time 0.000685s.
# 220711-13:27:13,319 nipype.workflow INFO:
# 	 [Job 150] Cached (_extract_mean_ts0).
# 220711-13:27:13,319 nipype.workflow INFO:
# 	 [Node] Setting-up "extract_striatum_signal.datasink" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_R_subject_id_544/datasink".
# 220711-13:27:13,322 nipype.workflow INFO:
# 	 [Job 151] Cached (_extract_mean_ts1).
# 220711-13:27:13,324 nipype.workflow INFO:
# 	 [Job 152] Cached (_extract_mean_ts0).
# 220711-13:27:13,327 nipype.workflow INFO:
# 	 [Job 153] Cached (_extract_mean_ts1).
# 220711-13:27:13,328 nipype.workflow INFO:
# 	 [Job 154] Cached (_extract_mean_ts0).
# 220711-13:27:13,330 nipype.workflow INFO:
# 	 [Job 155] Cached (_extract_mean_ts1).
# 220711-13:27:13,332 nipype.workflow INFO:
# 	 [Job 156] Cached (_extract_mean_ts0).
# 220711-13:27:13,334 nipype.workflow INFO:
# 	 [Job 157] Cached (_extract_mean_ts1).
# 220711-13:27:13,337 nipype.workflow INFO:
# 	 [Node] Executing "datasink" <nipype.interfaces.io.DataSink>
# 220711-13:27:13,341 nipype.workflow INFO:
# 	 [Node] Finished "datasink", elapsed time 0.001024s.
# 220711-13:27:14,920 nipype.workflow INFO:
# 	 [Job 68] Completed (extract_striatum_signal.datasink).
# 220711-13:27:14,923 nipype.workflow INFO:
# 	 [Job 69] Completed (extract_striatum_signal.datasink).
# 220711-13:27:14,926 nipype.workflow INFO:
# 	 [Job 70] Completed (extract_striatum_signal.datasink).
# 220711-13:27:14,928 nipype.workflow INFO:
# 	 [Job 71] Completed (extract_striatum_signal.datasink).
# 220711-13:27:14,930 nipype.workflow INFO:
# 	 [Job 72] Completed (extract_striatum_signal.datasink).
# 220711-13:27:14,932 nipype.workflow INFO:
# 	 [Job 73] Completed (extract_striatum_signal.datasink).
# 220711-13:27:14,936 nipype.workflow INFO:
# 	 [Job 74] Completed (extract_striatum_signal.datasink).
# 220711-13:27:14,938 nipype.workflow INFO:
# 	 [Job 75] Completed (extract_striatum_signal.datasink).
# 220711-13:27:14,940 nipype.workflow INFO:
# 	 [Job 76] Completed (extract_striatum_signal.datasink).
# 220711-13:27:14,941 nipype.workflow INFO:
# 	 [Job 77] Completed (extract_striatum_signal.datasink).
# 220711-13:27:14,943 nipype.workflow INFO:
# 	 [Job 78] Completed (extract_striatum_signal.datasink).
# 220711-13:27:14,944 nipype.workflow INFO:
# 	 [Job 79] Completed (extract_striatum_signal.datasink).
# 220711-13:27:14,946 nipype.workflow INFO:
# 	 [Job 80] Completed (extract_striatum_signal.datasink).
# 220711-13:27:14,947 nipype.workflow INFO:
# 	 [Job 81] Completed (extract_striatum_signal.datasink).
# 220711-13:27:14,948 nipype.workflow INFO:
# 	 [Job 82] Completed (extract_striatum_signal.datasink).
# 220711-13:27:14,949 nipype.workflow INFO:
# 	 [Job 83] Completed (extract_striatum_signal.datasink).
# 220711-13:27:14,953 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 24 jobs ready. Free memory (GB): 338.90/338.90, Free processors: 32/32.
# 220711-13:27:15,40 nipype.workflow INFO:
# 	 [Job 58] Cached (extract_striatum_signal.extract_mean_ts).
# 220711-13:27:15,44 nipype.workflow INFO:
# 	 [Job 59] Cached (extract_striatum_signal.extract_mean_ts).
# 220711-13:27:15,48 nipype.workflow INFO:
# 	 [Job 60] Cached (extract_striatum_signal.extract_mean_ts).
# 220711-13:27:15,52 nipype.workflow INFO:
# 	 [Job 61] Cached (extract_striatum_signal.extract_mean_ts).
# 220711-13:27:15,79 nipype.workflow INFO:
# 	 [Node] Setting-up "extract_striatum_signal.datasink" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_L_subject_id_548/datasink".
# 220711-13:27:15,89 nipype.workflow INFO:
# 	 [Node] Executing "datasink" <nipype.interfaces.io.DataSink>
# 220711-13:27:15,92 nipype.workflow INFO:
# 	 [Node] Finished "datasink", elapsed time 0.000693s.
# 220711-13:27:15,92 nipype.workflow INFO:
# 	 [Node] Setting-up "extract_striatum_signal.datasink" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_R_subject_id_548/datasink".
# 220711-13:27:15,112 nipype.workflow INFO:
# 	 [Node] Executing "datasink" <nipype.interfaces.io.DataSink>
# 220711-13:27:15,115 nipype.workflow INFO:
# 	 [Node] Setting-up "extract_striatum_signal.datasink" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_L_subject_id_549/datasink".
# 220711-13:27:15,116 nipype.workflow INFO:
# 	 [Node] Finished "datasink", elapsed time 0.001288s.
# 220711-13:27:15,128 nipype.workflow INFO:
# 	 [Node] Setting-up "extract_striatum_signal.datasink" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_R_subject_id_549/datasink".
# 220711-13:27:15,138 nipype.workflow INFO:
# 	 [Node] Executing "datasink" <nipype.interfaces.io.DataSink>
# 220711-13:27:15,140 nipype.workflow INFO:
# 	 [Node] Executing "datasink" <nipype.interfaces.io.DataSink>
# 220711-13:27:15,142 nipype.workflow INFO:
# 	 [Node] Finished "datasink", elapsed time 0.001001s.
# 220711-13:27:15,144 nipype.workflow INFO:
# 	 [Node] Finished "datasink", elapsed time 0.000768s.
# 220711-13:27:15,144 nipype.workflow INFO:
# 	 [Node] Setting-up "extract_striatum_signal.datasink" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_L_subject_id_551/datasink".
# 220711-13:27:15,155 nipype.workflow INFO:
# 	 [Node] Setting-up "extract_striatum_signal.datasink" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_R_subject_id_551/datasink".
# 220711-13:27:15,169 nipype.workflow INFO:
# 	 [Node] Executing "datasink" <nipype.interfaces.io.DataSink>
# 220711-13:27:15,171 nipype.workflow INFO:
# 	 [Node] Executing "datasink" <nipype.interfaces.io.DataSink>
# 220711-13:27:15,173 nipype.workflow INFO:
# 	 [Node] Finished "datasink", elapsed time 0.001026s.
# 220711-13:27:15,176 nipype.workflow INFO:
# 	 [Node] Finished "datasink", elapsed time 0.001344s.
# 220711-13:27:15,205 nipype.workflow INFO:
# 	 [Node] Setting-up "extract_striatum_signal.datasink" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_L_subject_id_552/datasink".
# 220711-13:27:15,218 nipype.workflow INFO:
# 	 [Job 158] Cached (_extract_mean_ts0).
# 220711-13:27:15,219 nipype.workflow INFO:
# 	 [Node] Setting-up "extract_striatum_signal.datasink" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_R_subject_id_552/datasink".
# 220711-13:27:15,222 nipype.workflow INFO:
# 	 [Job 159] Cached (_extract_mean_ts1).
# 220711-13:27:15,225 nipype.workflow INFO:
# 	 [Job 160] Cached (_extract_mean_ts0).
# 220711-13:27:15,224 nipype.workflow INFO:
# 	 [Node] Executing "datasink" <nipype.interfaces.io.DataSink>
# 220711-13:27:15,228 nipype.workflow INFO:
# 	 [Job 161] Cached (_extract_mean_ts1).
# 220711-13:27:15,229 nipype.workflow INFO:
# 	 [Node] Finished "datasink", elapsed time 0.001334s.
# 220711-13:27:15,231 nipype.workflow INFO:
# 	 [Job 162] Cached (_extract_mean_ts0).
# 220711-13:27:15,234 nipype.workflow INFO:
# 	 [Job 163] Cached (_extract_mean_ts1).
# 220711-13:27:15,236 nipype.workflow INFO:
# 	 [Job 164] Cached (_extract_mean_ts0).
# 220711-13:27:15,238 nipype.workflow INFO:
# 	 [Job 165] Cached (_extract_mean_ts1).
# 220711-13:27:15,237 nipype.workflow INFO:
# 	 [Node] Executing "datasink" <nipype.interfaces.io.DataSink>
# 220711-13:27:15,240 nipype.workflow INFO:
# 	 [Job 166] Cached (_extract_mean_ts0).
# 220711-13:27:15,242 nipype.workflow INFO:
# 	 [Job 167] Cached (_extract_mean_ts1).
# 220711-13:27:15,241 nipype.workflow INFO:
# 	 [Node] Finished "datasink", elapsed time 0.001155s.
# 220711-13:27:15,244 nipype.workflow INFO:
# 	 [Job 168] Cached (_extract_mean_ts0).
# 220711-13:27:15,246 nipype.workflow INFO:
# 	 [Job 169] Cached (_extract_mean_ts1).
# 220711-13:27:16,921 nipype.workflow INFO:
# 	 [Job 84] Completed (extract_striatum_signal.datasink).
# 220711-13:27:16,924 nipype.workflow INFO:
# 	 [Job 85] Completed (extract_striatum_signal.datasink).
# 220711-13:27:16,927 nipype.workflow INFO:
# 	 [Job 86] Completed (extract_striatum_signal.datasink).
# 220711-13:27:16,930 nipype.workflow INFO:
# 	 [Job 87] Completed (extract_striatum_signal.datasink).
# 220711-13:27:16,932 nipype.workflow INFO:
# 	 [Job 88] Completed (extract_striatum_signal.datasink).
# 220711-13:27:16,934 nipype.workflow INFO:
# 	 [Job 89] Completed (extract_striatum_signal.datasink).
# 220711-13:27:16,938 nipype.workflow INFO:
# 	 [Job 90] Completed (extract_striatum_signal.datasink).
# 220711-13:27:16,940 nipype.workflow INFO:
# 	 [Job 91] Completed (extract_striatum_signal.datasink).
# 220711-13:27:16,943 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 10 jobs ready. Free memory (GB): 338.90/338.90, Free processors: 32/32.
# 220711-13:27:17,28 nipype.workflow INFO:
# 	 [Job 62] Cached (extract_striatum_signal.extract_mean_ts).
# 220711-13:27:17,32 nipype.workflow INFO:
# 	 [Job 63] Cached (extract_striatum_signal.extract_mean_ts).
# 220711-13:27:17,36 nipype.workflow INFO:
# 	 [Job 64] Cached (extract_striatum_signal.extract_mean_ts).
# 220711-13:27:17,39 nipype.workflow INFO:
# 	 [Job 65] Cached (extract_striatum_signal.extract_mean_ts).
# 220711-13:27:17,43 nipype.workflow INFO:
# 	 [Job 66] Cached (extract_striatum_signal.extract_mean_ts).
# 220711-13:27:17,47 nipype.workflow INFO:
# 	 [Job 67] Cached (extract_striatum_signal.extract_mean_ts).
# 220711-13:27:17,65 nipype.workflow INFO:
# 	 [Node] Setting-up "extract_striatum_signal.datasink" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_L_subject_id_553/datasink".
# 220711-13:27:17,78 nipype.workflow INFO:
# 	 [Node] Setting-up "extract_striatum_signal.datasink" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_R_subject_id_553/datasink".
# 220711-13:27:17,111 nipype.workflow INFO:
# 	 [Node] Setting-up "extract_striatum_signal.datasink" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_L_subject_id_554/datasink".
# 220711-13:27:17,123 nipype.workflow INFO:
# 	 [Node] Executing "datasink" <nipype.interfaces.io.DataSink>
# 220711-13:27:17,124 nipype.workflow INFO:
# 	 [Node] Executing "datasink" <nipype.interfaces.io.DataSink>
# 220711-13:27:17,125 nipype.workflow INFO:
# 	 [Node] Executing "datasink" <nipype.interfaces.io.DataSink>
# 220711-13:27:17,126 nipype.workflow INFO:
# 	 [Node] Finished "datasink", elapsed time 0.00083s.
# 220711-13:27:17,128 nipype.workflow INFO:
# 	 [Node] Finished "datasink", elapsed time 0.0011s.
# 220711-13:27:17,129 nipype.workflow INFO:
# 	 [Node] Finished "datasink", elapsed time 0.001138s.
# 220711-13:27:17,137 nipype.workflow INFO:
# 	 [Node] Setting-up "extract_striatum_signal.datasink" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_R_subject_id_554/datasink".
# 220711-13:27:17,150 nipype.workflow INFO:
# 	 [Node] Executing "datasink" <nipype.interfaces.io.DataSink>
# 220711-13:27:17,155 nipype.workflow INFO:
# 	 [Node] Finished "datasink", elapsed time 0.00124s.
# 220711-13:27:18,923 nipype.workflow INFO:
# 	 [Job 92] Completed (extract_striatum_signal.datasink).
# 220711-13:27:18,926 nipype.workflow INFO:
# 	 [Job 93] Completed (extract_striatum_signal.datasink).
# 220711-13:27:18,929 nipype.workflow INFO:
# 	 [Job 94] Completed (extract_striatum_signal.datasink).
# 220711-13:27:18,931 nipype.workflow INFO:
# 	 [Job 95] Completed (extract_striatum_signal.datasink).
# 220711-13:27:18,936 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 6 jobs ready. Free memory (GB): 338.90/338.90, Free processors: 32/32.
# 220711-13:27:19,44 nipype.workflow INFO:
# 	 [Node] Setting-up "extract_striatum_signal.datasink" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_L_subject_id_555/datasink".
# 220711-13:27:19,59 nipype.workflow INFO:
# 	 [Node] Executing "datasink" <nipype.interfaces.io.DataSink>
# 220711-13:27:19,61 nipype.workflow INFO:
# 	 [Node] Setting-up "extract_striatum_signal.datasink" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_R_subject_id_555/datasink".
# 220711-13:27:19,63 nipype.workflow INFO:
# 	 [Node] Finished "datasink", elapsed time 0.001096s.
# 220711-13:27:19,68 nipype.workflow INFO:
# 	 [Node] Setting-up "extract_striatum_signal.datasink" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_L_subject_id_558/datasink".
# 220711-13:27:19,91 nipype.workflow INFO:
# 	 [Node] Setting-up "extract_striatum_signal.datasink" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_R_subject_id_558/datasink".
# 220711-13:27:19,95 nipype.workflow INFO:
# 	 [Node] Executing "datasink" <nipype.interfaces.io.DataSink>
# 220711-13:27:19,95 nipype.workflow INFO:
# 	 [Node] Executing "datasink" <nipype.interfaces.io.DataSink>
# 220711-13:27:19,99 nipype.workflow INFO:
# 	 [Node] Finished "datasink", elapsed time 0.001056s.
# 220711-13:27:19,99 nipype.workflow INFO:
# 	 [Node] Finished "datasink", elapsed time 0.00115s.
# 220711-13:27:19,100 nipype.workflow INFO:
# 	 [Node] Setting-up "extract_striatum_signal.datasink" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_L_subject_id_559/datasink".
# 220711-13:27:19,109 nipype.workflow INFO:
# 	 [Node] Executing "datasink" <nipype.interfaces.io.DataSink>
# 220711-13:27:19,110 nipype.workflow INFO:
# 	 [Node] Executing "datasink" <nipype.interfaces.io.DataSink>
# 220711-13:27:19,111 nipype.workflow INFO:
# 	 [Node] Finished "datasink", elapsed time 0.000575s.
# 220711-13:27:19,113 nipype.workflow INFO:
# 	 [Node] Finished "datasink", elapsed time 0.000795s.
# 220711-13:27:19,123 nipype.workflow INFO:
# 	 [Node] Setting-up "extract_striatum_signal.datasink" in "/data/workflow_folders/extract_striatum_signal/_mask_STR_R_subject_id_559/datasink".
# 220711-13:27:19,177 nipype.workflow INFO:
# 	 [Node] Executing "datasink" <nipype.interfaces.io.DataSink>
# 220711-13:27:19,181 nipype.workflow INFO:
# 	 [Node] Finished "datasink", elapsed time 0.000924s.
# 220711-13:27:20,925 nipype.workflow INFO:
# 	 [Job 96] Completed (extract_striatum_signal.datasink).
# 220711-13:27:20,928 nipype.workflow INFO:
# 	 [Job 97] Completed (extract_striatum_signal.datasink).
# 220711-13:27:20,931 nipype.workflow INFO:
# 	 [Job 98] Completed (extract_striatum_signal.datasink).
# 220711-13:27:20,933 nipype.workflow INFO:
# 	 [Job 99] Completed (extract_striatum_signal.datasink).
# 220711-13:27:20,936 nipype.workflow INFO:
# 	 [Job 100] Completed (extract_striatum_signal.datasink).
# 220711-13:27:20,937 nipype.workflow INFO:
# 	 [Job 101] Completed (extract_striatum_signal.datasink).
# 220711-13:27:20,942 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 0 jobs ready. Free memory (GB): 338.90/338.90, Free processors: 32/32.

# %% [markdown]
# 5) Again, visualize what the output data structure looks like using `!tree`

# %%
# !tree /data/extracted_signals
# Out:
# /data/extracted_signals
# └── extracted_timeseries
#     ├── _mask_STR_L_subject_id_197
#     │   ├── _extract_mean_ts0
#     │   │   └── sub-197_task-SAT_run-1_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     │   └── _extract_mean_ts1
#     │       └── sub-197_task-SAT_run-2_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     ├── _mask_STR_L_subject_id_372
#     │   ├── _extract_mean_ts0
#     │   │   └── sub-372_task-SAT_run-1_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     │   └── _extract_mean_ts1
#     │       └── sub-372_task-SAT_run-2_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     ├── _mask_STR_L_subject_id_381
#     │   ├── _extract_mean_ts0
#     │   │   └── sub-381_task-SAT_run-1_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     │   └── _extract_mean_ts1
#     │       └── sub-381_task-SAT_run-2_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     ├── _mask_STR_L_subject_id_471
#     │   ├── _extract_mean_ts0
#     │   │   └── sub-471_task-SAT_run-1_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     │   └── _extract_mean_ts1
#     │       └── sub-471_task-SAT_run-2_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     ├── _mask_STR_L_subject_id_483
#     │   ├── _extract_mean_ts0
#     │   │   └── sub-483_task-SAT_run-1_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     │   └── _extract_mean_ts1
#     │       └── sub-483_task-SAT_run-2_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     ├── _mask_STR_L_subject_id_498
#     │   ├── _extract_mean_ts0
#     │   │   └── sub-498_task-SAT_run-1_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     │   └── _extract_mean_ts1
#     │       └── sub-498_task-SAT_run-2_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     ├── _mask_STR_L_subject_id_523
#     │   ├── _extract_mean_ts0
#     │   │   └── sub-523_task-SAT_run-1_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     │   └── _extract_mean_ts1
#     │       └── sub-523_task-SAT_run-2_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     ├── _mask_STR_L_subject_id_544
#     │   ├── _extract_mean_ts0
#     │   │   └── sub-544_task-SAT_run-1_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     │   └── _extract_mean_ts1
#     │       └── sub-544_task-SAT_run-2_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     ├── _mask_STR_L_subject_id_548
#     │   ├── _extract_mean_ts0
#     │   │   └── sub-548_task-SAT_run-1_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     │   └── _extract_mean_ts1
#     │       └── sub-548_task-SAT_run-2_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     ├── _mask_STR_L_subject_id_549
#     │   ├── _extract_mean_ts0
#     │   │   └── sub-549_task-SAT_run-1_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     │   └── _extract_mean_ts1
#     │       └── sub-549_task-SAT_run-2_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     ├── _mask_STR_L_subject_id_551
#     │   ├── _extract_mean_ts0
#     │   │   └── sub-551_task-SAT_run-1_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     │   └── _extract_mean_ts1
#     │       └── sub-551_task-SAT_run-2_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     ├── _mask_STR_L_subject_id_552
#     │   ├── _extract_mean_ts0
#     │   │   └── sub-552_task-SAT_run-1_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     │   └── _extract_mean_ts1
#     │       └── sub-552_task-SAT_run-2_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     ├── _mask_STR_L_subject_id_553
#     │   ├── _extract_mean_ts0
#     │   │   └── sub-553_task-SAT_run-1_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     │   └── _extract_mean_ts1
#     │       └── sub-553_task-SAT_run-2_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     ├── _mask_STR_L_subject_id_554
#     │   ├── _extract_mean_ts0
#     │   │   └── sub-554_task-SAT_run-1_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     │   └── _extract_mean_ts1
#     │       └── sub-554_task-SAT_run-2_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     ├── _mask_STR_L_subject_id_555
#     │   ├── _extract_mean_ts0
#     │   │   └── sub-555_task-SAT_run-1_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     │   └── _extract_mean_ts1
#     │       └── sub-555_task-SAT_run-2_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     ├── _mask_STR_L_subject_id_558
#     │   ├── _extract_mean_ts0
#     │   │   └── sub-558_task-SAT_run-1_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     │   └── _extract_mean_ts1
#     │       └── sub-558_task-SAT_run-2_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     ├── _mask_STR_L_subject_id_559
#     │   ├── _extract_mean_ts0
#     │   │   └── sub-559_task-SAT_run-1_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     │   └── _extract_mean_ts1
#     │       └── sub-559_task-SAT_run-2_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     ├── _mask_STR_R_subject_id_197
#     │   ├── _extract_mean_ts0
#     │   │   └── sub-197_task-SAT_run-1_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     │   └── _extract_mean_ts1
#     │       └── sub-197_task-SAT_run-2_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     ├── _mask_STR_R_subject_id_372
#     │   ├── _extract_mean_ts0
#     │   │   └── sub-372_task-SAT_run-1_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     │   └── _extract_mean_ts1
#     │       └── sub-372_task-SAT_run-2_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     ├── _mask_STR_R_subject_id_381
#     │   ├── _extract_mean_ts0
#     │   │   └── sub-381_task-SAT_run-1_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     │   └── _extract_mean_ts1
#     │       └── sub-381_task-SAT_run-2_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     ├── _mask_STR_R_subject_id_471
#     │   ├── _extract_mean_ts0
#     │   │   └── sub-471_task-SAT_run-1_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     │   └── _extract_mean_ts1
#     │       └── sub-471_task-SAT_run-2_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     ├── _mask_STR_R_subject_id_483
#     │   ├── _extract_mean_ts0
#     │   │   └── sub-483_task-SAT_run-1_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     │   └── _extract_mean_ts1
#     │       └── sub-483_task-SAT_run-2_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     ├── _mask_STR_R_subject_id_498
#     │   ├── _extract_mean_ts0
#     │   │   └── sub-498_task-SAT_run-1_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     │   └── _extract_mean_ts1
#     │       └── sub-498_task-SAT_run-2_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     ├── _mask_STR_R_subject_id_523
#     │   ├── _extract_mean_ts0
#     │   │   └── sub-523_task-SAT_run-1_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     │   └── _extract_mean_ts1
#     │       └── sub-523_task-SAT_run-2_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     ├── _mask_STR_R_subject_id_544
#     │   ├── _extract_mean_ts0
#     │   │   └── sub-544_task-SAT_run-1_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     │   └── _extract_mean_ts1
#     │       └── sub-544_task-SAT_run-2_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     ├── _mask_STR_R_subject_id_548
#     │   ├── _extract_mean_ts0
#     │   │   └── sub-548_task-SAT_run-1_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     │   └── _extract_mean_ts1
#     │       └── sub-548_task-SAT_run-2_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     ├── _mask_STR_R_subject_id_549
#     │   ├── _extract_mean_ts0
#     │   │   └── sub-549_task-SAT_run-1_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     │   └── _extract_mean_ts1
#     │       └── sub-549_task-SAT_run-2_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     ├── _mask_STR_R_subject_id_551
#     │   ├── _extract_mean_ts0
#     │   │   └── sub-551_task-SAT_run-1_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     │   └── _extract_mean_ts1
#     │       └── sub-551_task-SAT_run-2_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     ├── _mask_STR_R_subject_id_552
#     │   ├── _extract_mean_ts0
#     │   │   └── sub-552_task-SAT_run-1_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     │   └── _extract_mean_ts1
#     │       └── sub-552_task-SAT_run-2_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     ├── _mask_STR_R_subject_id_553
#     │   ├── _extract_mean_ts0
#     │   │   └── sub-553_task-SAT_run-1_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     │   └── _extract_mean_ts1
#     │       └── sub-553_task-SAT_run-2_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     ├── _mask_STR_R_subject_id_554
#     │   ├── _extract_mean_ts0
#     │   │   └── sub-554_task-SAT_run-1_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     │   └── _extract_mean_ts1
#     │       └── sub-554_task-SAT_run-2_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     ├── _mask_STR_R_subject_id_555
#     │   ├── _extract_mean_ts0
#     │   │   └── sub-555_task-SAT_run-1_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     │   └── _extract_mean_ts1
#     │       └── sub-555_task-SAT_run-2_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     ├── _mask_STR_R_subject_id_558
#     │   ├── _extract_mean_ts0
#     │   │   └── sub-558_task-SAT_run-1_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     │   └── _extract_mean_ts1
#     │       └── sub-558_task-SAT_run-2_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#     └── _mask_STR_R_subject_id_559
#         ├── _extract_mean_ts0
#         │   └── sub-559_task-SAT_run-1_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#         └── _extract_mean_ts1
#             └── sub-559_task-SAT_run-2_space-MNI152NLin2009cAsym_desc-preproc_bold_ts.txt
#
# 103 directories, 68 files
